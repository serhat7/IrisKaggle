# %%
import numpy as np
import pandas as pd
import seaborn as sbn

# %%
df = pd.read_csv("IRIS.csv")

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
df.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica

# %%
df.head(10)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa
# 5           5.4          3.9           1.7          0.4  Iris-setosa
# 6           4.6          3.4           1.4          0.3  Iris-setosa
# 7           5.0          3.4           1.5          0.2  Iris-setosa
# 8           4.4          2.9           1.4          0.2  Iris-setosa
# 9           4.9          3.1           1.5          0.1  Iris-setosa

# %%
df.shape
# Out:
# (150, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.describe().T
# Out:
#               count      mean       std  min  25%   50%  75%  max
# sepal_length  150.0  5.843333  0.828066  4.3  5.1  5.80  6.4  7.9
# sepal_width   150.0  3.054000  0.433594  2.0  2.8  3.00  3.3  4.4
# petal_length  150.0  3.758667  1.764420  1.0  1.6  4.35  5.1  6.9
# petal_width   150.0  1.198667  0.763161  0.1  0.3  1.30  1.8  2.5

# %%
df["sepal_length"].std()
# Out:
# 0.8280661279778629

# %%
df["sepal_length"].mode()
# Out:
# 0    5.0
# Name: sepal_length, dtype: float64

# %%
df.isna().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
df.corr()
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.109369      0.871754     0.817954
# sepal_width      -0.109369     1.000000     -0.420516    -0.356544
# petal_length      0.871754    -0.420516      1.000000     0.962757
# petal_width       0.817954    -0.356544      0.962757     1.000000

# %%
corr = df.corr()
sbn.heatmap(corr, 
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values);

# %%
df["species"].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
df["species"].nunique()
# Out:
# 3

# %%
sbn.scatterplot(x="sepal_width", y="sepal_length", data=df);

# %%
sbn.jointplot(x = df["sepal_width"], y = df["sepal_length"],color="green");

# %%
sbn.scatterplot(x="sepal_width", y = "sepal_length", hue = "species", data=df);

# %%
df.value_counts().T
# Out:
# sepal_length  sepal_width  petal_length  petal_width  species
# 4.9           3.1          1.5           0.1          Iris-setosa        3
# 5.8           2.7          5.1           1.9          Iris-virginica     2
#               4.0          1.2           0.2          Iris-setosa        1
# 5.9           3.0          4.2           1.5          Iris-versicolor    1
# 6.2           3.4          5.4           2.3          Iris-virginica     1
#                                                                         ..
# 5.5           2.3          4.0           1.3          Iris-versicolor    1
#               2.4          3.7           1.0          Iris-versicolor    1
#                            3.8           1.1          Iris-versicolor    1
#               2.5          4.0           1.3          Iris-versicolor    1
# 7.9           3.8          6.4           2.0          Iris-virginica     1
# Length: 147, dtype: int64

# %%
sbn.violinplot(y="sepal_width",data=df)
# Out:
# <AxesSubplot:ylabel='sepal_width'>

# %%
sbn.displot(df["sepal_width"],bins=20,color="purple")

# %%
sbn.violinplot(y="sepal_length",x="species",data=df)
# Out:
# <AxesSubplot:xlabel='species', ylabel='sepal_length'>

# %%
sbn.countplot(x="species",data=df)
# Out:
# <AxesSubplot:xlabel='species', ylabel='count'>

# %%
sbn.jointplot(x=df["sepal_length"],y=df["sepal_width"],color="purple")

# %%
sbn.jointplot(x="sepal_length",y="sepal_width",data=df, kind="kde",color="purple")

# %%
sbn.scatterplot(x="petal_length",y="petal_width",data=df,color="purple")
# Out:
# <AxesSubplot:xlabel='petal_length', ylabel='petal_width'>

# %%
sbn.scatterplot(x="petal_length", y ="petal_width", hue="species", data = df)
# Out:
# <AxesSubplot:xlabel='petal_length', ylabel='petal_width'>

# %%
sbn.lmplot(x="petal_length",y="petal_width",data=df)

# %%
df.corr()["petal_length"]["petal_width"]
# Out:
# 0.9627570970509662

# %%
df["total_length"]=(df["petal_length"]+df["sepal_length"])

# %%
df["total_length"].mean()
# Out:
# 9.602000000000004

# %%
df["total_length"].std()
# Out:
# 2.5191739884121978

# %%
df.max()["sepal_length"]
# Out:
# 7.9

# %%
df[(df["sepal_length"]>5.5)&(df["species"]=="Iris-setosa")]
# Out:
#     sepal_length  sepal_width  petal_length  petal_width      species  \
# 14           5.8          4.0           1.2          0.2  Iris-setosa
# 15           5.7          4.4           1.5          0.4  Iris-setosa
# 18           5.7          3.8           1.7          0.3  Iris-setosa
#
#     total_length
# 14           7.0
# 15           7.2
# 18           7.4

# %%
df[(df["petal_length"] < 5) & (df["species"] == "Iris-virginica")].sort_values('species', axis = 0, ascending = False).head()[["sepal_length","sepal_width"]]
# Out:
#      sepal_length  sepal_width
# 106           4.9          2.5
# 121           5.6          2.8
# 123           6.3          2.7
# 126           6.2          2.8
# 127           6.1          3.0

# %%
df.groupby(["species"]).mean()
# Out:
#                  sepal_length  sepal_width  petal_length  petal_width  \
# species
# Iris-setosa             5.006        3.418         1.464        0.244
# Iris-versicolor         5.936        2.770         4.260        1.326
# Iris-virginica          6.588        2.974         5.552        2.026
#
#                  total_length
# species
# Iris-setosa             6.470
# Iris-versicolor        10.196
# Iris-virginica         12.140

# %%
df.groupby(["species"]).std()["petal_length"]
# Out:
# species
# Iris-setosa        0.173511
# Iris-versicolor    0.469911
# Iris-virginica     0.551895
# Name: petal_length, dtype: float64
